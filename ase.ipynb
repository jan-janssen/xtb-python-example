# %%
from ase.build import molecule

# %%
from xtb.ase.calculator import XTB

# %%
atoms = molecule('H2O')

# %%
atoms.calc = XTB(method="GFN2-xTB")

# %%
atoms.get_potential_energy()
# Out:
# -137.96777587302992

# %%
atoms.get_forces()
# Out:
# array([[-1.02505916e-19, -5.01736881e-15, -7.49514699e-01],
#        [ 2.30222065e-19, -1.53501989e-01,  3.74757349e-01],
#        [-1.27716149e-19,  1.53501989e-01,  3.74757349e-01]])
